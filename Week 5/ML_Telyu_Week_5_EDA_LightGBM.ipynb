# %% [markdown]
# <a href="https://colab.research.google.com/github/hanselkane/MachineLearning-Telyu/blob/main/Week%205/ML_Telyu_Week_5_EDA_LightGBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Make a directory to store kaggle token
# !mkdir ~/.kaggle # the '~' symbol is equal '/root'

import json
token ={"username":"ultranumb","key":"5f6e16afa53809c7c1817b1bb3f3242b"}
json_object = json.dumps(token, indent = 4)
  
# Writing to kaggle.json
with open("/root/.kaggle/kaggle.json", "w") as outfile:
    outfile.write(json_object)

# !chmod 600 ~/.kaggle/kaggle.json # Changing permission access to kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
# !kaggle competitions download santander-customer-transaction-prediction
# Out:
# Downloading santander-customer-transaction-prediction.zip to /content
#  96% 241M/250M [00:05<00:00, 41.4MB/s]
# 100% 250M/250M [00:05<00:00, 46.6MB/s]

# %%
# !unzip santander-customer-transaction-prediction.zip
# Out:
# Archive:  santander-customer-transaction-prediction.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold,KFold
import warnings
from six.moves import urllib
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('seaborn')
from scipy.stats import norm, skew

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
features = [c for c in train.columns if c not in ['ID_code', 'target']]
print(features)
# Out:
# ['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7', 'var_8', 'var_9', 'var_10', 'var_11', 'var_12', 'var_13', 'var_14', 'var_15', 'var_16', 'var_17', 'var_18', 'var_19', 'var_20', 'var_21', 'var_22', 'var_23', 'var_24', 'var_25', 'var_26', 'var_27', 'var_28', 'var_29', 'var_30', 'var_31', 'var_32', 'var_33', 'var_34', 'var_35', 'var_36', 'var_37', 'var_38', 'var_39', 'var_40', 'var_41', 'var_42', 'var_43', 'var_44', 'var_45', 'var_46', 'var_47', 'var_48', 'var_49', 'var_50', 'var_51', 'var_52', 'var_53', 'var_54', 'var_55', 'var_56', 'var_57', 'var_58', 'var_59', 'var_60', 'var_61', 'var_62', 'var_63', 'var_64', 'var_65', 'var_66', 'var_67', 'var_68', 'var_69', 'var_70', 'var_71', 'var_72', 'var_73', 'var_74', 'var_75', 'var_76', 'var_77', 'var_78', 'var_79', 'var_80', 'var_81', 'var_82', 'var_83', 'var_84', 'var_85', 'var_86', 'var_87', 'var_88', 'var_89', 'var_90', 'var_91', 'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97', 'var_98', 'var_99', 'var_100', 'var_101', 'var_102', 'var_103', 'var_104', 'var_105', 'var_106', 'var_107', 'var_108', 'var_109', 'var_110', 'var_111', 'var_112', 'var_113', 'var_114', 'var_115', 'var_116', 'var_117', 'var_118', 'var_119', 'var_120', 'var_121', 'var_122', 'var_123', 'var_124', 'var_125', 'var_126', 'var_127', 'var_128', 'var_129', 'var_130', 'var_131', 'var_132', 'var_133', 'var_134', 'var_135', 'var_136', 'var_137', 'var_138', 'var_139', 'var_140', 'var_141', 'var_142', 'var_143', 'var_144', 'var_145', 'var_146', 'var_147', 'var_148', 'var_149', 'var_150', 'var_151', 'var_152', 'var_153', 'var_154', 'var_155', 'var_156', 'var_157', 'var_158', 'var_159', 'var_160', 'var_161', 'var_162', 'var_163', 'var_164', 'var_165', 'var_166', 'var_167', 'var_168', 'var_169', 'var_170', 'var_171', 'var_172', 'var_173', 'var_174', 'var_175', 'var_176', 'var_177', 'var_178', 'var_179', 'var_180', 'var_181', 'var_182', 'var_183', 'var_184', 'var_185', 'var_186', 'var_187', 'var_188', 'var_189', 'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195', 'var_196', 'var_197', 'var_198', 'var_199']

# %%
train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# 25%         5.254075       9.883175     -11.200350       4.767700
# 50%         6.825000      11.108250      -4.833150       5.385100
# 75%         8.324100      12.261125       0.924800       6.003000
# max        13.188300      16.671400      17.251600       8.447700
#
#                var_7          var_8  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean       16.545850       0.284162  ...       3.234440       7.438408
# std         3.418076       3.332634  ...       4.559922       3.023272
# min         5.349700     -10.505500  ...     -14.093300      -2.691700
# 25%        13.943800      -2.317800  ...      -0.058825       5.157400
# 50%        16.456800       0.393700  ...       3.203600       7.347750
# 75%        19.102900       2.937900  ...       6.406200       9.512525
# max        27.691800      10.151300  ...      18.440900      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.927839       3.331774      17.993784      -0.142088
# std         1.478423       3.992030       3.135162       1.429372
# min        -3.814500     -11.783400       8.694400      -5.261000
# 25%         0.889775       0.584600      15.629800      -1.170700
# 50%         1.901300       3.396350      17.957950      -0.172700
# 75%         2.949500       6.205800      20.396525       0.829600
# max         8.402400      18.281800      27.928800       4.272900
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.303335       8.908158      15.870720      -3.326537
# std         5.454369       0.921625       3.010945      10.438015
# min       -14.209600       5.960600       6.299300     -38.852800
# 25%        -1.946925       8.252800      13.829700     -11.208475
# 50%         2.408900       8.888200      15.934050      -2.819550
# 75%         6.556725       9.593300      18.064725       4.836800
# max        18.321500      12.000400      26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
train.shape
# Out:
# (200000, 202)

# %%
train.head(5)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
#Check for Missing Values after Concatination

obs = train.isnull().sum().sort_values(ascending = False)
percent = round(train.isnull().sum().sort_values(ascending = False)/len(train)*100, 2)
pd.concat([obs, percent], axis = 1,keys= ['Number of Observations', 'Percent'])
# Out:
#          Number of Observations  Percent
# ID_code                       0      0.0
# var_136                       0      0.0
# var_126                       0      0.0
# var_127                       0      0.0
# var_128                       0      0.0
# ...                         ...      ...
# var_68                        0      0.0
# var_69                        0      0.0
# var_70                        0      0.0
# var_71                        0      0.0
# var_199                       0      0.0
#
# [202 rows x 2 columns]

# %%
target = train['target']
train = train.drop(["ID_code", "target"], axis=1)
sns.set_style('whitegrid')
sns.countplot(target)

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the train and test set")
sns.distplot(train[features].mean(axis=1),color="black", kde=True,bins=120, label='train')
sns.distplot(test[features].mean(axis=1),color="red", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(train[features].mean(axis=0),color="black", kde=True,bins=120, label='train')
sns.distplot(test[features].mean(axis=0),color="red", kde=True,bins=120, label='test')
plt.legend();plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of std values per rows in the train and test set")
sns.distplot(train[features].std(axis=1),color="blue",kde=True,bins=120, label='train')
sns.distplot(test[features].std(axis=1),color="green", kde=True,bins=120, label='test')
plt.legend(); plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(train[features].std(axis=0),color="blue", kde=True,bins=120, label='train')
sns.distplot(test[features].std(axis=0),color="green", kde=True,bins=120, label='test')
plt.legend();plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the train set")
sns.distplot(t0[features].mean(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].mean(axis=1),color="green", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train set")
sns.distplot(t0[features].mean(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].mean(axis=0),color="green", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
# Check the std of every row
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of standard deviation values per row in the train set")
sns.distplot(t0[features].std(axis=1),color="blue", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].std(axis=1),color="red", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target  == 0]
t1 = train.loc[target  == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of standard deviation values per column in the train set")
sns.distplot(t0[features].std(axis=0),color="blue", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].std(axis=0),color="red", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of skew values per row in the train set")
sns.distplot(t0[features].skew(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].skew(axis=1),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of skew values per column in the train set")
sns.distplot(t0[features].skew(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].skew(axis=0),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis values per row in the train set")
sns.distplot(t0[features].kurtosis(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].kurtosis(axis=1),color="green", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis values per column in the train set")
sns.distplot(t0[features].kurtosis(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].kurtosis(axis=0),color="green", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
t0 = train.loc[target == 0]
t1 = train.loc[target == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis values per column in the train set")
sns.distplot(t0[features].kurtosis(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].kurtosis(axis=0),color="green", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)         
PCA_train_x = PCA(2).fit_transform(train_scaled)
plt.scatter(PCA_train_x[:, 0], PCA_train_x[:, 1], c=target, cmap="copper_r")
plt.axis('off')
plt.colorbar()
plt.show()

# %%
from sklearn.decomposition import KernelPCA

lin_pca = KernelPCA(n_components = 2, kernel="linear", fit_inverse_transform=True)
rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.0433, fit_inverse_transform=True)
sig_pca = KernelPCA(n_components = 2, kernel="sigmoid", gamma=0.001, coef0=1, fit_inverse_transform=True)


plt.figure(figsize=(11, 4))
for subplot, pca, title in ((131, lin_pca, "Linear kernel"), (132, rbf_pca, "RBF kernel, $\gamma=0.04$"), 
                            (133, sig_pca, "Sigmoid kernel, $\gamma=10^{-3}, r=1$")):
       
    PCA_train_x = PCA(2).fit_transform(train_scaled)
    plt.subplot(subplot)
    plt.title(title, fontsize=14)
    plt.scatter(PCA_train_x[:, 0], PCA_train_x[:, 1], c=target, cmap="nipy_spectral_r")
    plt.xlabel("$z_1$", fontsize=18)
    if subplot == 131:
        plt.ylabel("$z_2$", fontsize=18, rotation=0)
    plt.grid(True)

plt.show()

# %%
# Make dummy data by partially copying the existing data
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.041,
    'learning_rate': 0.0083,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': -1,
    'shuffle':'true'
}

# %%
train.shape
# Out:
# (200000, 200)

# %%
num_folds = 11
features = [c for c in train.columns if c not in ['ID_code', 'target']]

folds = KFold(n_splits=num_folds, random_state=2319, shuffle=True)
oof = np.zeros(len(train))
getVal = np.zeros(len(train))
predictions = np.zeros(len(target))
feature_importance_df = pd.DataFrame()

print('Light GBM Model')
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    
    X_train, y_train = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_valid, y_valid = train.iloc[val_idx][features], target.iloc[val_idx]
    
    X_tr, y_tr = augment(X_train.values, y_train.values)
    X_tr = pd.DataFrame(X_tr)
    
    print("Fold idx:{}".format(fold_ + 1))
    trn_data = lgb.Dataset(X_tr, label=y_tr)
    val_data = lgb.Dataset(X_valid, label=y_valid)
    
    clf = lgb.train(param, trn_data, 500000, valid_sets = [trn_data, val_data], verbose_eval=1, early_stopping_rounds = 1)
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    getVal[val_idx]+= clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration) / folds.n_splits
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# Light GBM Model
# Fold idx:1
# [1]	training's auc: 0.580513	valid_1's auc: 0.568401
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.628299	valid_1's auc: 0.610648
# [3]	training's auc: 0.659932	valid_1's auc: 0.645938
# [4]	training's auc: 0.682919	valid_1's auc: 0.667449
# [5]	training's auc: 0.686996	valid_1's auc: 0.66935
# [6]	training's auc: 0.703997	valid_1's auc: 0.683989
# [7]	training's auc: 0.725225	valid_1's auc: 0.70326
# [8]	training's auc: 0.730326	valid_1's auc: 0.708249
# [9]	training's auc: 0.733857	valid_1's auc: 0.712673
# [10]	training's auc: 0.735788	valid_1's auc: 0.714718
# [11]	training's auc: 0.743182	valid_1's auc: 0.722729
# [12]	training's auc: 0.745765	valid_1's auc: 0.727235
# [13]	training's auc: 0.754775	valid_1's auc: 0.734778
# [14]	training's auc: 0.759831	valid_1's auc: 0.741085
# [15]	training's auc: 0.767998	valid_1's auc: 0.748066
# [16]	training's auc: 0.776987	valid_1's auc: 0.756593
# [17]	training's auc: 0.780728	valid_1's auc: 0.760951
# [18]	training's auc: 0.784795	valid_1's auc: 0.763494
# [19]	training's auc: 0.786786	valid_1's auc: 0.763739
# [20]	training's auc: 0.784942	valid_1's auc: 0.760702
# Early stopping, best iteration is:
# [19]	training's auc: 0.786786	valid_1's auc: 0.763739
# Fold idx:2
# [1]	training's auc: 0.580989	valid_1's auc: 0.583326
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.626849	valid_1's auc: 0.628461
# [3]	training's auc: 0.659199	valid_1's auc: 0.648099
# [4]	training's auc: 0.682282	valid_1's auc: 0.678295
# [5]	training's auc: 0.685565	valid_1's auc: 0.67981
# [6]	training's auc: 0.702074	valid_1's auc: 0.696558
# [7]	training's auc: 0.72298	valid_1's auc: 0.715833
# [8]	training's auc: 0.728775	valid_1's auc: 0.722252
# [9]	training's auc: 0.732211	valid_1's auc: 0.727125
# [10]	training's auc: 0.733856	valid_1's auc: 0.726942
# Early stopping, best iteration is:
# [9]	training's auc: 0.732211	valid_1's auc: 0.727125
# Fold idx:3
# [1]	training's auc: 0.579469	valid_1's auc: 0.579517
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.627082	valid_1's auc: 0.62076
# [3]	training's auc: 0.657171	valid_1's auc: 0.657151
# [4]	training's auc: 0.681636	valid_1's auc: 0.67974
# [5]	training's auc: 0.685001	valid_1's auc: 0.683226
# [6]	training's auc: 0.702276	valid_1's auc: 0.699846
# [7]	training's auc: 0.723622	valid_1's auc: 0.718553
# [8]	training's auc: 0.729345	valid_1's auc: 0.719751
# [9]	training's auc: 0.733937	valid_1's auc: 0.723945
# [10]	training's auc: 0.73628	valid_1's auc: 0.727705
# [11]	training's auc: 0.744656	valid_1's auc: 0.73541
# [12]	training's auc: 0.746788	valid_1's auc: 0.735954
# [13]	training's auc: 0.756618	valid_1's auc: 0.745361
# [14]	training's auc: 0.76195	valid_1's auc: 0.750385
# [15]	training's auc: 0.770507	valid_1's auc: 0.76047
# [16]	training's auc: 0.78004	valid_1's auc: 0.770062
# [17]	training's auc: 0.784125	valid_1's auc: 0.772377
# [18]	training's auc: 0.788355	valid_1's auc: 0.776259
# [19]	training's auc: 0.790104	valid_1's auc: 0.777765
# [20]	training's auc: 0.786984	valid_1's auc: 0.774084
# Early stopping, best iteration is:
# [19]	training's auc: 0.790104	valid_1's auc: 0.777765
# Fold idx:4
# [1]	training's auc: 0.581886	valid_1's auc: 0.569482
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.628853	valid_1's auc: 0.619978
# [3]	training's auc: 0.659822	valid_1's auc: 0.653258
# [4]	training's auc: 0.681956	valid_1's auc: 0.675755
# [5]	training's auc: 0.687468	valid_1's auc: 0.67846
# [6]	training's auc: 0.703921	valid_1's auc: 0.695841
# [7]	training's auc: 0.724039	valid_1's auc: 0.716693
# [8]	training's auc: 0.729683	valid_1's auc: 0.721696
# [9]	training's auc: 0.733551	valid_1's auc: 0.72753
# [10]	training's auc: 0.735018	valid_1's auc: 0.729243
# [11]	training's auc: 0.742403	valid_1's auc: 0.736173
# [12]	training's auc: 0.744214	valid_1's auc: 0.738846
# [13]	training's auc: 0.753323	valid_1's auc: 0.749404
# [14]	training's auc: 0.758889	valid_1's auc: 0.754785
# [15]	training's auc: 0.767065	valid_1's auc: 0.760652
# [16]	training's auc: 0.776445	valid_1's auc: 0.768719
# [17]	training's auc: 0.780128	valid_1's auc: 0.774454
# [18]	training's auc: 0.784771	valid_1's auc: 0.779505
# [19]	training's auc: 0.786558	valid_1's auc: 0.780328
# [20]	training's auc: 0.784826	valid_1's auc: 0.778176
# Early stopping, best iteration is:
# [19]	training's auc: 0.786558	valid_1's auc: 0.780328
# Fold idx:5
# [1]	training's auc: 0.580107	valid_1's auc: 0.585768
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.626224	valid_1's auc: 0.633901
# [3]	training's auc: 0.657505	valid_1's auc: 0.663229
# [4]	training's auc: 0.680027	valid_1's auc: 0.684573
# [5]	training's auc: 0.684821	valid_1's auc: 0.68791
# [6]	training's auc: 0.702163	valid_1's auc: 0.703755
# [7]	training's auc: 0.722893	valid_1's auc: 0.723643
# [8]	training's auc: 0.728488	valid_1's auc: 0.727486
# [9]	training's auc: 0.732549	valid_1's auc: 0.731024
# [10]	training's auc: 0.734176	valid_1's auc: 0.733008
# [11]	training's auc: 0.74175	valid_1's auc: 0.738637
# [12]	training's auc: 0.743999	valid_1's auc: 0.740002
# [13]	training's auc: 0.753504	valid_1's auc: 0.751038
# [14]	training's auc: 0.757824	valid_1's auc: 0.754907
# [15]	training's auc: 0.767106	valid_1's auc: 0.763408
# [16]	training's auc: 0.776282	valid_1's auc: 0.76988
# [17]	training's auc: 0.780511	valid_1's auc: 0.77476
# [18]	training's auc: 0.785201	valid_1's auc: 0.780192
# [19]	training's auc: 0.787199	valid_1's auc: 0.782117
# [20]	training's auc: 0.785484	valid_1's auc: 0.781897
# Early stopping, best iteration is:
# [19]	training's auc: 0.787199	valid_1's auc: 0.782117
# Fold idx:6
# [1]	training's auc: 0.580701	valid_1's auc: 0.576309
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.628832	valid_1's auc: 0.62717
# [3]	training's auc: 0.660061	valid_1's auc: 0.655627
# [4]	training's auc: 0.682612	valid_1's auc: 0.682682
# [5]	training's auc: 0.687054	valid_1's auc: 0.685972
# [6]	training's auc: 0.704439	valid_1's auc: 0.69964
# [7]	training's auc: 0.725887	valid_1's auc: 0.716596
# [8]	training's auc: 0.731153	valid_1's auc: 0.718834
# [9]	training's auc: 0.734671	valid_1's auc: 0.72127
# [10]	training's auc: 0.736811	valid_1's auc: 0.722214
# [11]	training's auc: 0.743583	valid_1's auc: 0.731863
# [12]	training's auc: 0.746144	valid_1's auc: 0.732477
# [13]	training's auc: 0.755379	valid_1's auc: 0.742273
# [14]	training's auc: 0.759773	valid_1's auc: 0.745983
# [15]	training's auc: 0.767508	valid_1's auc: 0.756708
# [16]	training's auc: 0.776175	valid_1's auc: 0.764629
# [17]	training's auc: 0.780537	valid_1's auc: 0.766558
# [18]	training's auc: 0.785635	valid_1's auc: 0.7719
# [19]	training's auc: 0.787277	valid_1's auc: 0.773449
# [20]	training's auc: 0.785561	valid_1's auc: 0.771561
# Early stopping, best iteration is:
# [19]	training's auc: 0.787277	valid_1's auc: 0.773449
# Fold idx:7
# [1]	training's auc: 0.580766	valid_1's auc: 0.570527
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.626637	valid_1's auc: 0.616194
# [3]	training's auc: 0.65839	valid_1's auc: 0.647411
# [4]	training's auc: 0.68065	valid_1's auc: 0.66933
# [5]	training's auc: 0.684689	valid_1's auc: 0.67612
# [6]	training's auc: 0.701556	valid_1's auc: 0.690553
# [7]	training's auc: 0.723205	valid_1's auc: 0.71262
# [8]	training's auc: 0.728801	valid_1's auc: 0.715909
# [9]	training's auc: 0.732732	valid_1's auc: 0.719881
# [10]	training's auc: 0.734416	valid_1's auc: 0.720001
# [11]	training's auc: 0.742405	valid_1's auc: 0.726759
# [12]	training's auc: 0.745031	valid_1's auc: 0.729185
# [13]	training's auc: 0.754541	valid_1's auc: 0.73909
# [14]	training's auc: 0.758775	valid_1's auc: 0.745634
# [15]	training's auc: 0.766667	valid_1's auc: 0.753536
# [16]	training's auc: 0.775728	valid_1's auc: 0.765004
# [17]	training's auc: 0.779623	valid_1's auc: 0.769556
# [18]	training's auc: 0.784442	valid_1's auc: 0.777268
# [19]	training's auc: 0.786314	valid_1's auc: 0.778908
# [20]	training's auc: 0.784697	valid_1's auc: 0.777298
# Early stopping, best iteration is:
# [19]	training's auc: 0.786314	valid_1's auc: 0.778908
# Fold idx:8
# [1]	training's auc: 0.581058	valid_1's auc: 0.58725
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.629396	valid_1's auc: 0.626391
# [3]	training's auc: 0.660217	valid_1's auc: 0.658616
# [4]	training's auc: 0.6834	valid_1's auc: 0.675665
# [5]	training's auc: 0.687243	valid_1's auc: 0.6803
# [6]	training's auc: 0.703921	valid_1's auc: 0.700615
# [7]	training's auc: 0.725118	valid_1's auc: 0.721559
# [8]	training's auc: 0.730457	valid_1's auc: 0.72802
# [9]	training's auc: 0.733277	valid_1's auc: 0.730144
# [10]	training's auc: 0.735227	valid_1's auc: 0.732288
# [11]	training's auc: 0.742535	valid_1's auc: 0.739291
# [12]	training's auc: 0.744591	valid_1's auc: 0.741468
# [13]	training's auc: 0.754576	valid_1's auc: 0.749622
# [14]	training's auc: 0.759522	valid_1's auc: 0.755776
# [15]	training's auc: 0.768111	valid_1's auc: 0.762128
# [16]	training's auc: 0.777398	valid_1's auc: 0.772172
# [17]	training's auc: 0.78177	valid_1's auc: 0.774791
# [18]	training's auc: 0.786015	valid_1's auc: 0.779959
# [19]	training's auc: 0.787607	valid_1's auc: 0.782162
# [20]	training's auc: 0.786508	valid_1's auc: 0.781303
# Early stopping, best iteration is:
# [19]	training's auc: 0.787607	valid_1's auc: 0.782162
# Fold idx:9
# [1]	training's auc: 0.582109	valid_1's auc: 0.594109
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.627956	valid_1's auc: 0.631682
# [3]	training's auc: 0.658465	valid_1's auc: 0.654193
# [4]	training's auc: 0.681699	valid_1's auc: 0.682114
# [5]	training's auc: 0.686053	valid_1's auc: 0.685489
# [6]	training's auc: 0.702597	valid_1's auc: 0.702116
# [7]	training's auc: 0.723414	valid_1's auc: 0.72232
# [8]	training's auc: 0.728601	valid_1's auc: 0.729396
# [9]	training's auc: 0.731783	valid_1's auc: 0.733026
# [10]	training's auc: 0.732791	valid_1's auc: 0.731718
# Early stopping, best iteration is:
# [9]	training's auc: 0.731783	valid_1's auc: 0.733026
# Fold idx:10
# [1]	training's auc: 0.580496	valid_1's auc: 0.587987
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.627394	valid_1's auc: 0.630548
# [3]	training's auc: 0.658285	valid_1's auc: 0.660099
# [4]	training's auc: 0.681865	valid_1's auc: 0.685398
# [5]	training's auc: 0.685927	valid_1's auc: 0.687512
# [6]	training's auc: 0.702827	valid_1's auc: 0.706322
# [7]	training's auc: 0.723625	valid_1's auc: 0.730464
# [8]	training's auc: 0.728596	valid_1's auc: 0.736967
# [9]	training's auc: 0.732822	valid_1's auc: 0.737573
# [10]	training's auc: 0.734211	valid_1's auc: 0.738007
# [11]	training's auc: 0.741686	valid_1's auc: 0.750561
# [12]	training's auc: 0.743939	valid_1's auc: 0.75113
# [13]	training's auc: 0.754024	valid_1's auc: 0.757532
# [14]	training's auc: 0.758017	valid_1's auc: 0.761456
# [15]	training's auc: 0.765852	valid_1's auc: 0.768926
# [16]	training's auc: 0.775073	valid_1's auc: 0.778053
# [17]	training's auc: 0.779648	valid_1's auc: 0.781768
# [18]	training's auc: 0.78441	valid_1's auc: 0.787188
# [19]	training's auc: 0.786244	valid_1's auc: 0.789652
# [20]	training's auc: 0.784032	valid_1's auc: 0.789344
# Early stopping, best iteration is:
# [19]	training's auc: 0.786244	valid_1's auc: 0.789652
# Fold idx:11
# [1]	training's auc: 0.581197	valid_1's auc: 0.565594
# Training until validation scores don't improve for 1 rounds.
# [2]	training's auc: 0.628305	valid_1's auc: 0.619097
# [3]	training's auc: 0.659081	valid_1's auc: 0.65154
# [4]	training's auc: 0.682613	valid_1's auc: 0.670751
# [5]	training's auc: 0.686963	valid_1's auc: 0.672816
# [6]	training's auc: 0.70356	valid_1's auc: 0.691907
# [7]	training's auc: 0.724635	valid_1's auc: 0.712924
# [8]	training's auc: 0.729756	valid_1's auc: 0.71778
# [9]	training's auc: 0.733402	valid_1's auc: 0.724342
# [10]	training's auc: 0.734946	valid_1's auc: 0.72607
# [11]	training's auc: 0.7424	valid_1's auc: 0.732331
# [12]	training's auc: 0.744874	valid_1's auc: 0.735029
# [13]	training's auc: 0.754342	valid_1's auc: 0.745596
# [14]	training's auc: 0.758934	valid_1's auc: 0.748753
# [15]	training's auc: 0.76733	valid_1's auc: 0.757976
# [16]	training's auc: 0.776744	valid_1's auc: 0.768503
# [17]	training's auc: 0.780636	valid_1's auc: 0.772763
# [18]	training's auc: 0.785633	valid_1's auc: 0.774863
# [19]	training's auc: 0.787302	valid_1's auc: 0.77535
# [20]	training's auc: 0.785008	valid_1's auc: 0.774159
# Early stopping, best iteration is:
# [19]	training's auc: 0.787302	valid_1's auc: 0.77535
# CV score: 0.69315

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)
best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
